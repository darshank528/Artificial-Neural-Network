# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![](https://drive.google.com/uc?export=view&id=1rCuDwACEFFqFub19iKhRkGJzWPBc1bAx)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![](https://drive.google.com/uc?export=view&id=1TialkDEDyTJn_-Rdn_NS1AkBwGmPPVZx)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# ![](https://drive.google.com/uc?export=view&id=1Jb7AdGqPKpewzBNKNAoV3Ne8DREUzhia)
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# ![](https://drive.google.com/uc?export=view&id=1_LOEGchxOKm6GHZ54jwyXTWxLJ7qfUDp)
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
# %tensorflow_version 1.x
import time

import numpy as np
import tensorflow as tf
import sys
sys.path.append('\content\sample_data')

import sample_data.utils as utils
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:55, 270kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
count_words = Counter(int_words)
total_words = len(int_words)
frequency = {word:count/total_words for word,count in count_words.items()}
drop_prob = {word:1-np.sqrt(threshold/freq) for word,freq in frequency.items()}
# The final subsampled word list
train_words = [word for word in int_words if random.random()<(1-drop_prob[word])]

print(len(train_words))
# Out:
# 4627176

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    value_R = np.random.randint(1,window_size+1)
    start_index = idx-value_R if (idx-value_R)>0 else 0
    end_index = idx+value_R
    target = list(set(words[start_index:idx]+words[idx+1:end_index+1]))
    
    return target

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![](https://drive.google.com/uc?export=view&id=1_gFD47fvWfMrK2onnUMTiLjur_ydicIt)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,shape=[None],name="input")
    labels = tf.placeholder(tf.int32,shape=[None,None],name="ouput")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200   # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=[n_vocab,n_embedding],minval=-1,maxval=1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs)# use tf.nn.embedding_lookup to get the hidden layer output
print(embed.shape)
# Out:
# (?, 200)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=(n_vocab,n_embedding),stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w,biases=softmax_b,labels=labels,inputs=embed,num_sampled=n_sampled,num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6939 0.0402 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6051 0.0222 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5223 0.0224 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6121 0.0228 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5337 0.0228 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5279 0.0223 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5626 0.0228 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5490 0.0223 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4520 0.0225 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4555 0.0226 sec/batch
# Nearest to where: storehouses, goldsworthy, cavalier, diff, trampled, good, man, paton,
# Nearest to however: musical, sustainability, decimated, uematsu, hyrum, rgen, redrawing, foundationalism,
# Nearest to these: vocalizations, canr, delmarva, shoemaker, midrashim, mexico, inserting, grammys,
# Nearest to this: projective, clements, australia, amphetamine, dabbled, poker, maximizes, a,
# Nearest to into: confirming, treviso, letting, royce, lil, dispositions, nobuo, unknown,
# Nearest to most: footing, miserere, holocaust, isthmian, dart, harking, beyond, escherichia,
# Nearest to one: genocide, develop, zero, rhadamanthus, whistleblower, altamira, nubia, deregulation,
# Nearest to eight: ceremonies, intellectual, peninsula, decree, lund, journ, specifically, axioms,
# Nearest to behind: marching, chime, shareholding, timid, mull, acylation, syngman, beauregard,
# Nearest to proposed: functionalist, directorship, einaudi, popularize, delft, luxembourgian, lyle, ramp,
# Nearest to taking: oppress, vineyards, contemplating, inkjet, constitutionalism, feet, harpsichordist, menu,
# Nearest to gold: thanks, unamuno, endeavoured, dreadnoughts, kyiv, connors, hassel, invertible,
# Nearest to liberal: mamoru, chord, mapmaking, acrylic, extinguishing, valuable, ambulance, recieved,
# Nearest to hit: gabab, ecstatic, kritik, frist, adi, exploring, imprinted, reinhardt,
# Nearest to accepted: feared, fiefs, dosing, spellman, macrolides, dwell, dweller, monarchist,
# Nearest to universe: swordsmanship, nuns, faye, xenarthra, noncanonical, dept, gideon, galesburg,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4860 0.0239 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3476 0.0229 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3075 0.0226 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2212 0.0227 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1888 0.0222 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1586 0.0226 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0970 0.0225 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0728 0.0219 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9952 0.0220 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9810 0.0223 sec/batch
# Nearest to where: good, storehouses, goldsworthy, diff, cavalier, man, later, contributed,
# Nearest to however: musical, uematsu, decimated, these, sustainability, redrawing, rgen, dmc,
# Nearest to these: vocalizations, mexico, however, canr, shoemaker, delmarva, implicated, adaptation,
# Nearest to this: operation, a, australia, analogous, projective, poker, fields, cartoon,
# Nearest to into: confirming, letting, unknown, treviso, royce, centred, gallery, dispositions,
# Nearest to most: beyond, reserve, footing, phone, dart, holocaust, rush, draft,
# Nearest to one: york, genocide, promote, electricity, deregulation, changed, view, develop,
# Nearest to eight: intellectual, ceremonies, decree, peninsula, mathematician, october, war, zealand,
# Nearest to behind: marching, chime, acylation, shareholding, mull, timid, focused, personality,
# Nearest to proposed: functionalist, popularize, directorship, delft, einaudi, wide, mountain, luxembourgian,
# Nearest to taking: oppress, menu, feet, rightist, fact, obed, posterity, into,
# Nearest to gold: thanks, unamuno, quebec, aboriginal, dreadnoughts, endeavoured, invertible, hassel,
# Nearest to liberal: valuable, mapmaking, chord, buy, acrylic, recieved, ambulance, excess,
# Nearest to hit: adi, ecstatic, zimmerman, exploring, substantiated, full, nylon, lattice,
# Nearest to accepted: feared, fiefs, dwell, dosing, forbidden, spellman, monarchist, creation,
# Nearest to universe: swordsmanship, galesburg, faye, dominated, dept, puritan, fillings, xenarthra,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9276 0.0232 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9015 0.0219 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8602 0.0221 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8495 0.0221 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8170 0.0222 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8119 0.0221 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7978 0.0228 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7804 0.0221 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7849 0.0223 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7939 0.0219 sec/batch
# Nearest to where: goldsworthy, good, storehouses, man, trampled, confucian, cavalier, diff,
# Nearest to however: musical, decimated, sustainability, uematsu, evenings, redrawing, mangrove, these,
# Nearest to these: vocalizations, mexico, shoemaker, canr, delmarva, however, implicated, surveyed,
# Nearest to this: a, projective, operation, analogous, poker, cartoon, hurst, australia,
# Nearest to into: confirming, letting, unknown, treviso, royce, worm, dispositions, taking,
# Nearest to most: holocaust, footing, beyond, dart, reserve, harking, phone, rush,
# Nearest to one: zero, relinquished, york, electricity, deregulation, reynolds, promote, three,
# Nearest to eight: october, lund, mathematician, zealand, intellectual, decree, ceremonies, war,
# Nearest to behind: marching, chime, shareholding, timid, acylation, focused, lyapunov, digest,
# Nearest to proposed: functionalist, popularize, directorship, ramp, inflections, delft, einaudi, lyle,
# Nearest to taking: oppress, menu, feet, posterity, contemplating, obed, developers, rightist,
# Nearest to gold: thanks, unamuno, endeavoured, dreadnoughts, invertible, pastor, aeneas, quebec,
# Nearest to liberal: chord, valuable, mapmaking, ambulance, buy, extinguishing, acrylic, mamoru,
# Nearest to hit: exploring, zimmerman, adi, sessions, lends, ecstatic, pan, disparagingly,
# Nearest to accepted: feared, fiefs, dwell, surroundings, monarchist, forbidden, dosing, imagines,
# Nearest to universe: dominated, swordsmanship, puritan, galesburg, dept, elliptic, faye, fillings,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7831 0.0231 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7398 0.0220 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6936 0.0227 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7067 0.0218 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7623 0.0222 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7032 0.0220 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7113 0.0225 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7455 0.0222 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7120 0.0218 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6888 0.0217 sec/batch
# Nearest to where: confucian, storehouses, goldsworthy, trampled, good, diff, cavalier, paton,
# Nearest to however: sustainability, decimated, hyrum, uematsu, redrawing, evenings, musical, dmc,
# Nearest to these: vocalizations, shoemaker, delmarva, canr, mexico, zhan, surveyed, however,
# Nearest to this: a, projective, poker, amphetamine, analogous, maximizes, clements, smile,
# Nearest to into: confirming, letting, unknown, treviso, royce, worm, papal, maternal,
# Nearest to most: holocaust, footing, dart, beyond, isthmian, hereby, hitchhikers, wherein,
# Nearest to one: zero, six, eight, three, york, relinquished, deregulation, boston,
# Nearest to eight: one, mathematician, october, six, zealand, lund, seven, war,
# Nearest to behind: marching, chime, shareholding, timid, mull, lyapunov, syngman, novoselic,
# Nearest to proposed: functionalist, popularize, luxembourgian, directorship, tully, lyle, ramp, inflections,
# Nearest to taking: oppress, contemplating, kremlin, menu, vineyards, obed, constitutionalism, developers,
# Nearest to gold: thanks, endeavoured, unamuno, dreadnoughts, aeneas, invertible, pastor, sichuan,
# Nearest to liberal: behest, buy, mapmaking, chord, sbs, mamoru, ambulance, extinguishing,
# Nearest to hit: exploring, zimmerman, adi, ecstatic, sessions, lends, re, pan,
# Nearest to accepted: feared, dwell, fiefs, surroundings, mifflin, forbidden, dosing, monarchist,
# Nearest to universe: dominated, swordsmanship, dept, galesburg, faye, puritan, elliptic, sulphur,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6744 0.0231 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6771 0.0225 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5848 0.0225 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6596 0.0229 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6314 0.0220 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6229 0.0219 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5981 0.0164 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5783 0.0231 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4954 0.0227 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5147 0.0219 sec/batch
# Nearest to where: confucian, storehouses, trampled, good, goldsworthy, cavalier, underrepresented, diff,
# Nearest to however: sustainability, redrawing, decimated, hyrum, these, uematsu, evenings, mangrove,
# Nearest to these: vocalizations, delmarva, shoemaker, however, zhan, above, canr, conquistadors,
# Nearest to this: a, projective, amphetamine, analogous, poker, smile, maximizes, wearer,
# Nearest to into: letting, confirming, unknown, treviso, worm, royce, sampled, bombings,
# Nearest to most: holocaust, dart, footing, beyond, succ, escherichia, wherein, introduced,
# Nearest to one: eight, zero, six, three, york, d, boston, nobel,
# Nearest to eight: one, mathematician, october, six, seven, observances, nine, politician,
# Nearest to behind: marching, chime, shareholding, mull, timid, lyapunov, beauregard, novoselic,
# Nearest to proposed: functionalist, popularize, luxembourgian, ramp, inflections, lyle, delft, tully,
# Nearest to taking: oppress, contemplating, constitutionalism, vineyards, menu, inkjet, kremlin, obed,
# Nearest to gold: thanks, dreadnoughts, endeavoured, aeneas, invertible, unamuno, sichuan, hassel,
# Nearest to liberal: mapmaking, behest, mamoru, sbs, bootlegging, buy, democrats, hcf,
# Nearest to hit: zimmerman, exploring, lends, adi, sessions, albuquerque, re, ecstatic,
# Nearest to accepted: feared, forbidden, dwell, surroundings, fiefs, monarchist, dweller, dosing,
# Nearest to universe: swordsmanship, dept, dominated, faye, cracking, mnemonics, galesburg, puritan,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4894 0.0237 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5154 0.0223 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4657 0.0224 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5260 0.0220 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4932 0.0220 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4962 0.0217 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4759 0.0220 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4102 0.0226 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4405 0.0220 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4173 0.0224 sec/batch
# Nearest to where: confucian, trampled, good, goldsworthy, man, storehouses, maximum, diff,
# Nearest to however: sustainability, decimated, hyrum, redrawing, uematsu, evenings, dmc, these,
# Nearest to these: vocalizations, shoemaker, delmarva, above, zhan, exactly, however, canr,
# Nearest to this: a, amphetamine, analogous, projective, wearer, poker, clements, shuffling,
# Nearest to into: letting, confirming, treviso, unknown, worm, sampled, bombings, royce,
# Nearest to most: holocaust, dart, succ, footing, beyond, pradesh, escherichia, stamina,
# Nearest to one: zero, three, eight, six, electricity, boston, york, lojban,
# Nearest to eight: one, mathematician, journ, october, gaetano, clara, lund, six,
# Nearest to behind: marching, chime, shareholding, mull, lyapunov, timid, klondike, beauregard,
# Nearest to proposed: functionalist, luxembourgian, directorship, tully, ramp, inflections, popularize, delft,
# Nearest to taking: oppress, vineyards, contemplating, menu, constitutionalism, inkjet, rightist, endnotes,
# Nearest to gold: thanks, dreadnoughts, endeavoured, sichuan, aeneas, unamuno, shale, egregious,
# Nearest to liberal: democrats, mapmaking, suffrage, sbs, mamoru, behest, bootlegging, buy,
# Nearest to hit: zimmerman, exploring, re, valiant, gabab, sessions, adi, albuquerque,
# Nearest to accepted: feared, forbidden, dwell, surroundings, monarchist, fiefs, dweller, desires,
# Nearest to universe: dept, swordsmanship, cracking, abms, dominated, mnemonics, taming, galesburg,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4313 0.0237 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3869 0.0227 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4125 0.0218 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3818 0.0222 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3974 0.0223 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4182 0.0225 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3935 0.0226 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3840 0.0230 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3870 0.0218 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3465 0.0222 sec/batch
# Nearest to where: confucian, trampled, maximum, goldsworthy, good, man, divide, storehouses,
# Nearest to however: sustainability, decimated, hyrum, redrawing, evenings, offences, dmc, rebellions,
# Nearest to these: vocalizations, delmarva, above, shoemaker, implicated, canr, muad, exactly,
# Nearest to this: a, amphetamine, projective, analogous, poker, inevitable, shuffling, maximizes,
# Nearest to into: letting, confirming, worm, treviso, unknown, bombings, parchment, dispositions,
# Nearest to most: holocaust, succ, dart, beyond, escherichia, stamina, pradesh, phone,
# Nearest to one: zero, three, eight, six, waldo, boston, reynolds, york,
# Nearest to eight: one, october, journ, mathematician, gaetano, lund, j, six,
# Nearest to behind: marching, chime, shareholding, lyapunov, mull, novoselic, klondike, beauregard,
# Nearest to proposed: functionalist, luxembourgian, directorship, inflections, cartoonish, popularize, ramp, tully,
# Nearest to taking: oppress, vineyards, menu, constitutionalism, inkjet, abortifacient, endnotes, contemplating,
# Nearest to gold: thanks, dreadnoughts, aeneas, endeavoured, unamuno, sichuan, shale, abundant,
# Nearest to liberal: democrats, mapmaking, suffrage, sbs, behest, hcf, bootlegging, mamoru,
# Nearest to hit: zimmerman, re, exploring, gabab, valiant, my, sessions, adi,
# Nearest to accepted: feared, forbidden, surroundings, dwell, summons, desires, duly, dweller,
# Nearest to universe: dept, swordsmanship, cracking, abms, coset, sulphur, dominated, taming,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3647 0.0227 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3888 0.0216 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3532 0.0217 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3784 0.0217 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3964 0.0216 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3720 0.0218 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3920 0.0221 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3650 0.0219 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3164 0.0220 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3226 0.0224 sec/batch
# Nearest to where: trampled, goldsworthy, confucian, man, good, underrepresented, storehouses, maximum,
# Nearest to however: sustainability, decimated, hyrum, sovereignty, redrawing, offences, evenings, ppc,
# Nearest to these: vocalizations, delmarva, shoemaker, above, implicated, muad, canr, midrashim,
# Nearest to this: a, amphetamine, analogous, shuffling, projective, inevitable, poker, maximizes,
# Nearest to into: letting, confirming, bombings, unknown, treviso, worm, parchment, negotiating,
# Nearest to most: holocaust, distractions, stamina, succ, dart, collective, prevailing, escherichia,
# Nearest to one: zero, three, six, eight, esa, greer, exalts, sq,
# Nearest to eight: one, j, gaetano, journ, six, october, fawkes, mathematician,
# Nearest to behind: marching, chime, shareholding, mull, lyapunov, novoselic, gnawing, beauregard,
# Nearest to proposed: functionalist, directorship, luxembourgian, tully, cartoonish, inflections, popularize, ramp,
# Nearest to taking: oppress, transcendent, constitutionalism, abortifacient, inkjet, endnotes, contemplating, vineyards,
# Nearest to gold: dreadnoughts, thanks, aeneas, abundant, sichuan, shale, senayan, unamuno,
# Nearest to liberal: democrats, suffrage, behest, mapmaking, unconditional, sbs, hcf, vested,
# Nearest to hit: zimmerman, re, gabab, sessions, valiant, my, garcia, exploring,
# Nearest to accepted: forbidden, feared, surroundings, dwell, monarchist, summons, desires, duly,
# Nearest to universe: cracking, swordsmanship, dept, coset, abms, taming, thackeray, mnemonics,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3305 0.0232 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2706 0.0221 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3765 0.0217 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3728 0.0218 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4006 0.0218 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2819 0.0225 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2991 0.0222 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3350 0.0221 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2165 0.0220 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3171 0.0227 sec/batch
# Nearest to where: trampled, goldsworthy, man, confucian, robins, detroiters, good, underrepresented,
# Nearest to however: decimated, sustainability, hyrum, redrawing, ppc, sovereignty, offences, evenings,
# Nearest to these: vocalizations, shoemaker, delmarva, above, midrashim, muad, inserting, canr,
# Nearest to this: a, amphetamine, shuffling, analogous, projective, maximizes, inevitable, gateways,
# Nearest to into: letting, treviso, confirming, bombings, negotiating, worm, parchment, unknown,
# Nearest to most: holocaust, distractions, dart, pradesh, collective, wtro, stamina, hereby,
# Nearest to one: zero, three, eight, six, greer, esa, waldo, boston,
# Nearest to eight: one, six, seven, five, gaetano, mathematician, j, nine,
# Nearest to behind: marching, chime, shareholding, beauregard, novoselic, gnawing, klondike, mull,
# Nearest to proposed: functionalist, luxembourgian, directorship, tully, elections, ninety, popularize, odic,
# Nearest to taking: oppress, abortifacient, constitutionalism, kremlin, endnotes, vineyards, rightist, canticles,
# Nearest to gold: dreadnoughts, thanks, shale, aeneas, senayan, sichuan, abundant, powerpuff,
# Nearest to liberal: democrats, suffrage, mapmaking, unconditional, hcf, sbs, epileptic, behest,
# Nearest to hit: zimmerman, re, sessions, valiant, my, gabab, albuquerque, ure,
# Nearest to accepted: forbidden, feared, surroundings, dwell, desires, monarchist, duly, summons,
# Nearest to universe: swordsmanship, cracking, coset, abms, dept, mnemonics, noncanonical, taming,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3204 0.0228 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2678 0.0224 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3271 0.0102 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2370 0.0218 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2260 0.0219 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2370 0.0225 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2256 0.0221 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2039 0.0216 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2300 0.0222 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1892 0.0217 sec/batch
# Nearest to where: trampled, man, goldsworthy, good, maximum, robins, confucian, underrepresented,
# Nearest to however: decimated, hyrum, sustainability, redrawing, sovereignty, evenings, offences, ppc,
# Nearest to these: vocalizations, delmarva, muad, implicated, above, midrashim, shoemaker, canr,
# Nearest to this: a, amphetamine, projective, shuffling, analogous, gateways, perforce, maximizes,
# Nearest to into: letting, bombings, confirming, treviso, parchment, worm, maille, aerial,
# Nearest to most: minas, distractions, pradesh, wtro, collective, gascon, succ, dart,
# Nearest to one: zero, three, six, eight, greer, sq, esa, relinquished,
# Nearest to eight: one, six, gaetano, zero, journ, seven, october, five,
# Nearest to behind: marching, chime, shareholding, gnawing, klondike, mull, novoselic, polyurethane,
# Nearest to proposed: functionalist, luxembourgian, directorship, odic, elections, popularize, tully, ninety,
# Nearest to taking: oppress, abortifacient, vineyards, transcendent, constitutionalism, obed, transferring, rightist,
# Nearest to gold: dreadnoughts, thanks, shale, abundant, sichuan, senayan, powerpuff, aeneas,
# Nearest to liberal: democrats, suffrage, unconditional, mapmaking, afganistan, behest, hcf, sbs,
# Nearest to hit: zimmerman, re, sessions, gabab, my, valiant, run, inhale,
# Nearest to accepted: forbidden, feared, surroundings, dwell, duly, monarchist, dweller, desires,
# Nearest to universe: swordsmanship, cracking, coset, noncanonical, mnemonics, ecclesiasticus, dept, elliptic,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2289 0.0228 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2392 0.0215 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2364 0.0216 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1453 0.0216 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1714 0.0221 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1848 0.0218 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1831 0.0221 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1610 0.0223 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1691 0.0219 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1671 0.0221 sec/batch
# Nearest to where: trampled, man, maximum, goldsworthy, robins, senna, quit, annihilation,
# Nearest to however: sustainability, decimated, hyrum, ppc, sovereignty, offences, redrawing, grammarians,
# Nearest to these: vocalizations, delmarva, implicated, muad, above, midrashim, canr, shoemaker,
# Nearest to this: a, amphetamine, shuffling, projective, analogous, poker, that, inevitable,
# Nearest to into: letting, worm, confirming, maille, treviso, parchment, bombings, fic,
# Nearest to most: dart, pradesh, gascon, succ, collective, holocaust, stamina, dealbata,
# Nearest to one: zero, three, six, eight, greer, sq, esa, two,
# Nearest to eight: one, six, five, zero, gaetano, journ, october, total,
# Nearest to behind: marching, chime, shareholding, gnawing, polyurethane, klondike, mull, balloon,
# Nearest to proposed: functionalist, directorship, odic, luxembourgian, ninety, constitutive, elections, inflections,
# Nearest to taking: oppress, abortifacient, vineyards, transferring, canticles, constitutionalism, transcendent, rightist,
# Nearest to gold: dreadnoughts, thanks, shale, abundant, nickel, aeneas, senayan, powerpuff,
# Nearest to liberal: democrats, suffrage, unconditional, hcf, mapmaking, behest, afganistan, proponents,
# Nearest to hit: zimmerman, gabab, inhale, my, re, sessions, valiant, throws,
# Nearest to accepted: forbidden, surroundings, dwell, feared, duly, macrolides, monarchist, summons,
# Nearest to universe: swordsmanship, coset, cracking, noncanonical, observation, ecclesiasticus, taming, formulated,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1767 0.0232 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2324 0.0224 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1615 0.0226 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1247 0.0227 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1799 0.0221 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1683 0.0217 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2011 0.0218 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1526 0.0219 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1513 0.0221 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1713 0.0223 sec/batch
# Nearest to where: man, trampled, goldsworthy, detroiters, maximum, robins, senna, quit,
# Nearest to however: sustainability, decimated, hyrum, ppc, sovereignty, evenings, redrawing, grammarians,
# Nearest to these: vocalizations, delmarva, implicated, muad, canr, mexico, stockpiles, above,
# Nearest to this: a, amphetamine, analogous, shuffling, inevitable, projective, kinetics, compresses,
# Nearest to into: letting, confirming, worm, bombings, parchment, treviso, unknown, fic,
# Nearest to most: dart, succ, stamina, escherichia, distractions, transforms, collective, pradesh,
# Nearest to one: zero, six, three, eight, greer, two, esa, four,
# Nearest to eight: one, six, five, gaetano, nine, journ, j, zero,
# Nearest to behind: marching, chime, shareholding, gnawing, polyurethane, novoselic, klondike, recoiled,
# Nearest to proposed: functionalist, directorship, odic, luxembourgian, ninety, constitutive, elections, tully,
# Nearest to taking: oppress, abortifacient, transferring, vineyards, transcendent, catchers, constitutionalism, rightist,
# Nearest to gold: shale, dreadnoughts, abundant, nickel, thanks, ores, senayan, aeneas,
# Nearest to liberal: democrats, suffrage, unconditional, mapmaking, afganistan, proponents, hcf, epileptic,
# Nearest to hit: zimmerman, gabab, inhale, re, sessions, my, valiant, airplay,
# Nearest to accepted: forbidden, surroundings, dwell, feared, summons, monarchist, duly, macrolides,
# Nearest to universe: coset, noncanonical, taming, swordsmanship, cracking, formulated, ecclesiasticus, faint,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2082 0.0233 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1605 0.0221 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1935 0.0222 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2027 0.0217 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1521 0.0219 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1130 0.0221 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1739 0.0225 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1175 0.0217 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1707 0.0220 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1997 0.0218 sec/batch
# Nearest to where: man, trampled, detroiters, goldsworthy, robins, senna, quit, lmann,
# Nearest to however: hyrum, sustainability, decimated, sovereignty, redrawing, ppc, grammarians, vorder,
# Nearest to these: vocalizations, delmarva, muad, midrashim, implicated, fleur, shoemaker, above,
# Nearest to this: a, amphetamine, inevitable, shuffling, analogous, perforce, trofim, asks,
# Nearest to into: bombings, letting, confirming, treviso, worm, negotiating, fic, polisario,
# Nearest to most: distractions, collective, dart, pradesh, gascon, holocaust, prevailing, hereby,
# Nearest to one: zero, six, three, eight, greer, two, five, four,
# Nearest to eight: one, six, five, zero, nine, three, seven, two,
# Nearest to behind: marching, shareholding, gnawing, chime, polyurethane, novoselic, klondike, mull,
# Nearest to proposed: functionalist, directorship, odic, luxembourgian, jailed, elections, ninety, tully,
# Nearest to taking: oppress, abortifacient, transcendent, transferring, obed, constitutionalism, vineyards, canticles,
# Nearest to gold: shale, abundant, nickel, dreadnoughts, ores, thanks, aeneas, wept,
# Nearest to liberal: democrats, unconditional, suffrage, afganistan, mapmaking, holds, proponents, epileptic,
# Nearest to hit: zimmerman, re, sessions, inhale, ure, gabab, valiant, airplay,
# Nearest to accepted: forbidden, surroundings, dwell, duly, monarchist, feared, dua, macrolides,
# Nearest to universe: noncanonical, coset, copernicus, swordsmanship, taming, ecclesiasticus, formulated, observation,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2387 0.0227 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1192 0.0220 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1322 0.0220 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1478 0.0216 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0385 0.0216 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1385 0.0220 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1551 0.0219 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1522 0.0216 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1891 0.0044 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1306 0.0221 sec/batch
# Nearest to where: trampled, man, detroiters, goldsworthy, robins, lmann, quit, senna,
# Nearest to however: decimated, hyrum, sustainability, sovereignty, redrawing, grammarians, vorder, ppc,
# Nearest to these: vocalizations, delmarva, midrashim, muad, stockpiles, erratically, fleur, mexico,
# Nearest to this: a, shuffling, amphetamine, analogous, inevitable, projective, kinetics, compresses,
# Nearest to into: treviso, letting, bombings, confirming, worm, polisario, negotiating, centred,
# Nearest to most: distractions, gascon, pradesh, dart, prevailing, collective, transforms, succ,
# Nearest to one: zero, three, six, eight, two, greer, five, four,
# Nearest to eight: one, six, zero, nine, five, three, seven, two,
# Nearest to behind: marching, shareholding, chime, gnawing, recoiled, polyurethane, shook, balloon,
# Nearest to proposed: functionalist, directorship, odic, luxembourgian, elections, ninety, jailed, constitutive,
# Nearest to taking: oppress, abortifacient, transferring, transcendent, vineyards, blocker, constitutionalism, obed,
# Nearest to gold: shale, nickel, abundant, dreadnoughts, thanks, ores, powerpuff, wept,
# Nearest to liberal: democrats, mapmaking, afganistan, suffrage, holds, epileptic, unconditional, devlin,
# Nearest to hit: zimmerman, re, airplay, sessions, inhale, ure, kills, my,
# Nearest to accepted: forbidden, surroundings, duly, dwell, macrolides, exclusivity, motionless, monarchist,
# Nearest to universe: noncanonical, swordsmanship, ecclesiasticus, coset, copernicus, observation, taming, beauty,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0843 0.0226 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0685 0.0218 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1140 0.0219 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0581 0.0217 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0774 0.0220 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0496 0.0218 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0970 0.0215 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1006 0.0215 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1311 0.0217 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0095 0.0220 sec/batch
# Nearest to where: trampled, man, detroiters, robins, goldsworthy, mabuse, senna, quit,
# Nearest to however: decimated, sustainability, hyrum, redrawing, sovereignty, grammarians, vorder, ppc,
# Nearest to these: vocalizations, delmarva, muad, midrashim, stockpiles, endpin, fleur, implicated,
# Nearest to this: a, amphetamine, inevitable, shuffling, kinetics, analogous, palsy, asks,
# Nearest to into: worm, letting, treviso, confirming, parchment, polisario, bombings, flaps,
# Nearest to most: gascon, dart, pradesh, dealbata, distractions, prevailing, faunas, cta,
# Nearest to one: zero, three, six, eight, two, greer, sq, five,
# Nearest to eight: one, six, five, zero, nine, three, seven, two,
# Nearest to behind: marching, shareholding, chime, gnawing, recoiled, shook, klondike, polyurethane,
# Nearest to proposed: functionalist, directorship, odic, luxembourgian, ninety, constitutive, jailed, equations,
# Nearest to taking: oppress, abortifacient, transcendent, vineyards, transferring, rightist, psychosomatic, fatal,
# Nearest to gold: shale, nickel, abundant, dreadnoughts, ores, thanks, wept, medals,
# Nearest to liberal: democrats, suffrage, afganistan, ashcroft, mapmaking, malenkov, proponents, holds,
# Nearest to hit: airplay, zimmerman, inhale, sessions, throws, re, upward, ure,
# Nearest to accepted: forbidden, surroundings, duly, motionless, exclusivity, dwell, macrolides, monarchist,
# Nearest to universe: coset, noncanonical, ecclesiasticus, copernicus, observation, cracking, swordsmanship, formulated,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0200 0.0229 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0366 0.0217 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0189 0.0219 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0403 0.0221 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0686 0.0220 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0585 0.0218 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0706 0.0220 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1051 0.0222 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0316 0.0223 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0346 0.0221 sec/batch
# Nearest to where: trampled, man, detroiters, robins, senna, amperes, quit, goldsworthy,
# Nearest to however: sustainability, redrawing, sovereignty, hyrum, vorder, decimated, grammarians, evenings,
# Nearest to these: vocalizations, delmarva, implicated, muad, midrashim, fleur, mexico, erratically,
# Nearest to this: a, inevitable, amphetamine, shuffling, kinetics, clicking, compresses, asks,
# Nearest to into: worm, letting, confirming, treviso, detergents, maille, flaps, parchment,
# Nearest to most: dart, gascon, distractions, dinitrogen, stamina, transforms, malted, succ,
# Nearest to one: zero, six, three, eight, two, greer, four, five,
# Nearest to eight: one, six, zero, five, three, nine, seven, two,
# Nearest to behind: marching, shareholding, chime, gnawing, recoiled, balloon, klondike, shook,
# Nearest to proposed: functionalist, directorship, odic, luxembourgian, elections, constitutive, ninety, equations,
# Nearest to taking: oppress, abortifacient, vineyards, transcendent, transferring, psychosomatic, limelight, blocker,
# Nearest to gold: ores, nickel, shale, thanks, abundant, wept, dreadnoughts, medals,
# Nearest to liberal: democrats, afganistan, mapmaking, holds, collectivism, suffrage, ashcroft, proponents,
# Nearest to hit: inhale, airplay, zimmerman, gabab, ure, throws, upward, re,
# Nearest to accepted: forbidden, surroundings, duly, denethor, dosing, dwell, dua, exclusivity,
# Nearest to universe: noncanonical, ecclesiasticus, coset, copernicus, swordsmanship, cracking, taming, observation,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0661 0.0225 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0833 0.0219 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0554 0.0226 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0638 0.0222 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0535 0.0221 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0646 0.0224 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0763 0.0221 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0734 0.0221 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0807 0.0218 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0611 0.0223 sec/batch
# Nearest to where: man, trampled, detroiters, senna, quit, goldsworthy, robins, mabuse,
# Nearest to however: redrawing, sustainability, decimated, vorder, sovereignty, hyrum, grammarians, evenings,
# Nearest to these: vocalizations, delmarva, mexico, fleur, midrashim, erratically, muad, endpin,
# Nearest to this: a, inevitable, amphetamine, shuffling, asks, kinetics, perforce, analogous,
# Nearest to into: worm, confirming, treviso, before, fic, letting, parchment, polisario,
# Nearest to most: distractions, dart, pradesh, gascon, prevailing, predecessors, scythians, hereby,
# Nearest to one: zero, six, eight, three, two, greer, four, five,
# Nearest to eight: one, six, zero, five, nine, three, seven, two,
# Nearest to behind: marching, gnawing, shareholding, chime, recoiled, shook, polyurethane, balloon,
# Nearest to proposed: functionalist, directorship, odic, tully, jailed, luxembourgian, balfour, constitutive,
# Nearest to taking: oppress, abortifacient, vineyards, transcendent, merv, psychosomatic, rumoured, limelight,
# Nearest to gold: ores, nickel, abundant, shale, dreadnoughts, thanks, wept, mania,
# Nearest to liberal: democrats, afganistan, ashcroft, holds, mapmaking, suffrage, malenkov, collectivism,
# Nearest to hit: inhale, airplay, re, gabab, zimmerman, kills, ure, upward,
# Nearest to accepted: forbidden, duly, surroundings, exclusivity, monarchist, denethor, motionless, dosing,
# Nearest to universe: copernicus, ecclesiasticus, noncanonical, taming, swordsmanship, killian, faint, observation,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0477 0.0226 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0200 0.0215 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0501 0.0214 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0569 0.0217 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0772 0.0224 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1196 0.0220 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1292 0.0214 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0450 0.0220 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0332 0.0216 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0560 0.0217 sec/batch
# Nearest to where: man, trampled, detroiters, amperes, senna, curdling, robins, goldsworthy,
# Nearest to however: sustainability, grammarians, vorder, redrawing, sovereignty, decimated, evenings, passive,
# Nearest to these: vocalizations, delmarva, midrashim, muad, fleur, erratically, mexico, zeroes,
# Nearest to this: a, inevitable, amphetamine, shuffling, compresses, asks, kinetics, that,
# Nearest to into: worm, confirming, treviso, before, polisario, letting, fic, suffocation,
# Nearest to most: distractions, gascon, dart, pradesh, prevailing, hereby, collective, anglophone,
# Nearest to one: zero, six, three, eight, two, four, five, greer,
# Nearest to eight: one, six, zero, five, nine, three, seven, four,
# Nearest to behind: marching, shareholding, gnawing, chime, recoiled, shook, novoselic, balloon,
# Nearest to proposed: functionalist, odic, directorship, jailed, tully, elections, luxembourgian, demilitarization,
# Nearest to taking: oppress, abortifacient, rumoured, vineyards, transcendent, merv, psychosomatic, starting,
# Nearest to gold: ores, nickel, shale, abundant, medals, dreadnoughts, thanks, wept,
# Nearest to liberal: democrats, holds, mapmaking, collectivism, ashcroft, afganistan, proponents, peshitta,
# Nearest to hit: inhale, kills, ure, airplay, re, zimmerman, blacksmith, gabab,
# Nearest to accepted: forbidden, duly, monarchist, exclusivity, surroundings, denethor, motionless, dwell,
# Nearest to universe: noncanonical, copernicus, ecclesiasticus, killian, observation, taming, satchel, swordsmanship,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9629 0.0232 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0336 0.0226 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0217 0.0219 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0499 0.0219 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0543 0.0222 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0321 0.0210 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0202 0.0222 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0071 0.0222 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0137 0.0219 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9682 0.0218 sec/batch
# Nearest to where: trampled, detroiters, man, amperes, senna, goldsworthy, mabuse, curdling,
# Nearest to however: grammarians, redrawing, vorder, sustainability, sovereignty, passive, decimated, evenings,
# Nearest to these: vocalizations, delmarva, midrashim, mexico, muad, erratically, stockpiles, windsurfing,
# Nearest to this: a, amphetamine, inevitable, shuffling, compresses, clicking, meritocratic, analogous,
# Nearest to into: worm, confirming, letting, before, treviso, fic, detergents, raping,
# Nearest to most: distractions, pradesh, gascon, prevailing, dealbata, hereby, composed, dinitrogen,
# Nearest to one: zero, six, eight, three, two, four, nine, five,
# Nearest to eight: one, six, zero, nine, three, five, seven, two,
# Nearest to behind: marching, shareholding, chime, gnawing, recoiled, shook, dunst, novoselic,
# Nearest to proposed: functionalist, odic, directorship, equations, tully, constitutive, ninety, demilitarization,
# Nearest to taking: abortifacient, oppress, rumoured, transcendent, psychosomatic, merv, vineyards, starting,
# Nearest to gold: ores, nickel, shale, abundant, medals, wept, dreadnoughts, thanks,
# Nearest to liberal: democrats, holds, ashcroft, collectivism, mapmaking, afganistan, peshitta, malenkov,
# Nearest to hit: inhale, kills, plow, zimmerman, re, airplay, kohoutek, humvee,
# Nearest to accepted: forbidden, duly, motionless, dwell, macrolides, denethor, dua, dosing,
# Nearest to universe: noncanonical, copernicus, ecclesiasticus, killian, taming, observation, cracking, swordsmanship,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9792 0.0229 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9510 0.0218 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0015 0.0222 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0229 0.0217 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0071 0.0221 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9972 0.0221 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8974 0.0226 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9635 0.0226 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9445 0.0219 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9897 0.0222 sec/batch
# Nearest to where: detroiters, trampled, amperes, robins, senna, man, curdling, mabuse,
# Nearest to however: grammarians, redrawing, sovereignty, vorder, sustainability, decimated, evenings, passive,
# Nearest to these: vocalizations, delmarva, midrashim, some, fleur, muad, mexico, stockpiles,
# Nearest to this: a, inevitable, amphetamine, shuffling, that, kinetics, palsy, compresses,
# Nearest to into: worm, before, detergents, confirming, treviso, letting, polisario, luminary,
# Nearest to most: gascon, composed, distractions, pradesh, prevailing, dealbata, anglophone, escherichia,
# Nearest to one: zero, six, eight, three, two, four, five, nine,
# Nearest to eight: one, six, zero, five, three, nine, two, four,
# Nearest to behind: chime, marching, shareholding, gnawing, recoiled, shook, dunst, klondike,
# Nearest to proposed: functionalist, odic, directorship, tully, demilitarization, jailed, constitutive, ninety,
# Nearest to taking: abortifacient, oppress, transcendent, psychosomatic, merv, vineyards, rumoured, blocker,
# Nearest to gold: ores, nickel, medals, shale, abundant, thanks, wept, dreadnoughts,
# Nearest to liberal: democrats, ashcroft, afganistan, mapmaking, holds, microcebus, peshitta, malenkov,
# Nearest to hit: inhale, airplay, kills, gabab, glycerol, plow, kohoutek, turn,
# Nearest to accepted: forbidden, duly, exclusivity, dua, dosing, macrolides, surroundings, denethor,
# Nearest to universe: copernicus, noncanonical, ecclesiasticus, observation, coset, killian, weinberg, cracking,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0070 0.0229 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0147 0.0217 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9768 0.0215 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9918 0.0215 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0386 0.0224 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9621 0.0220 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9736 0.0217 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9908 0.0216 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9866 0.0219 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0120 0.0216 sec/batch
# Nearest to where: trampled, amperes, detroiters, senna, robins, man, lmann, quit,
# Nearest to however: redrawing, vorder, evenings, grammarians, sovereignty, sustainability, decimated, intersubjectivity,
# Nearest to these: vocalizations, delmarva, midrashim, muad, mexico, fleur, implicated, some,
# Nearest to this: a, inevitable, amphetamine, shuffling, coincide, that, encoded, asks,
# Nearest to into: worm, confirming, before, letting, treviso, luminary, placenta, detergents,
# Nearest to most: gascon, anglophone, composed, distractions, hereby, escherichia, pradesh, matzoh,
# Nearest to one: zero, six, eight, three, two, four, nine, five,
# Nearest to eight: one, six, zero, nine, three, five, four, seven,
# Nearest to behind: marching, gnawing, chime, shareholding, shook, recoiled, balloon, dunst,
# Nearest to proposed: functionalist, odic, directorship, demilitarization, popularize, constitutive, tully, lyle,
# Nearest to taking: abortifacient, oppress, merv, vineyards, psychosomatic, rumoured, starting, blocker,
# Nearest to gold: ores, medals, nickel, thanks, shale, wept, abundant, dreadnoughts,
# Nearest to liberal: democrats, afganistan, holds, ashcroft, mapmaking, microcebus, collectivism, peshitta,
# Nearest to hit: inhale, glycerol, humvee, airplay, ure, culhwch, upward, trumps,
# Nearest to accepted: forbidden, duly, denethor, exclusivity, dosing, dua, macrolides, ginzberg,
# Nearest to universe: copernicus, noncanonical, ecclesiasticus, killian, observation, taming, swordsmanship, satchel,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9989 0.0228 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9823 0.0219 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9751 0.0218 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0042 0.0219 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0238 0.0220 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0281 0.0218 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9562 0.0225 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9548 0.0226 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9642 0.0214 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0439 0.0221 sec/batch
# Nearest to where: detroiters, trampled, senna, man, amperes, robins, lmann, local,
# Nearest to however: redrawing, grammarians, sovereignty, vorder, sustainability, decimated, evenings, passive,
# Nearest to these: vocalizations, delmarva, midrashim, some, fleur, designating, zeroes, mexico,
# Nearest to this: a, inevitable, coincide, shuffling, amphetamine, that, the, kinetics,
# Nearest to into: worm, before, confirming, treviso, luminary, placenta, detergents, chaldea,
# ...
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8648 0.0222 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8896 0.0219 sec/batch
# Nearest to where: a, in, amperes, senna, it, at, tezuka, manukau,
# Nearest to however: mahajanapadas, vorder, and, intersubjectivity, these, it, the, most,
# Nearest to these: are, all, atlanteans, however, some, vocalizations, callet, designating,
# Nearest to this: a, the, was, that, which, inevitable, for, fact,
# Nearest to into: before, the, worm, forming, starts, through, detergents, otherness,
# Nearest to most: and, also, known, to, is, since, the, include,
# Nearest to one: three, zero, six, eight, four, nine, two, five,
# Nearest to eight: one, six, zero, three, nine, four, seven, five,
# Nearest to behind: pawn, shareholding, denny, biome, datum, recoiled, dunst, explains,
# Nearest to proposed: functionalist, odic, explain, worked, herschel, cyndi, argued, tully,
# Nearest to taking: organized, rumoured, merv, accordion, blocker, abortifacient, transcendent, vineyards,
# Nearest to gold: medals, silver, medalist, olympics, precious, wept, ounce, mania,
# Nearest to liberal: democrats, reynolds, microcebus, enrolls, bootlegging, afganistan, tory, mapmaking,
# Nearest to hit: showed, selling, kohoutek, plow, run, skinner, orientation, danny,
# Nearest to accepted: forbidden, motionless, dosing, offered, duly, complicate, macrolides, observationally,
# Nearest to universe: bang, satchel, noncanonical, hubble, copernicus, cosmic, ultimate, superheroes,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8485 0.0224 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8420 0.0225 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8251 0.0226 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8400 0.0225 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8528 0.0221 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8682 0.0221 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8618 0.0219 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8617 0.0217 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8607 0.0219 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8644 0.0217 sec/batch
# Nearest to where: a, in, it, amperes, senna, germantown, manukau, at,
# Nearest to however: vorder, mahajanapadas, intersubjectivity, and, in, gracchi, the, beginning,
# Nearest to these: atlanteans, vocalizations, are, callet, ejected, all, some, delmarva,
# Nearest to this: a, the, is, that, as, inevitable, in, for,
# Nearest to into: the, before, worm, forming, through, starts, chaldea, eukaryotes,
# Nearest to most: also, and, known, is, to, since, other, include,
# Nearest to one: three, six, zero, eight, four, two, nine, five,
# Nearest to eight: one, six, three, zero, four, seven, nine, five,
# Nearest to behind: pawn, biome, datum, shareholding, denny, recoiled, dunst, explains,
# Nearest to proposed: functionalist, odic, explain, worked, modified, cyndi, tully, indicates,
# Nearest to taking: organized, merv, accordion, rumoured, vineyards, blocker, transcendent, abortifacient,
# Nearest to gold: medals, silver, ounce, precious, medalist, mania, coin, feat,
# Nearest to liberal: democrats, reynolds, microcebus, afganistan, enrolls, bootlegging, tory, reassure,
# Nearest to hit: selling, kohoutek, run, showed, inhale, glycerol, trainers, plow,
# Nearest to accepted: forbidden, motionless, dosing, sociale, observationally, duly, offered, complicate,
# Nearest to universe: bang, noncanonical, satchel, copernicus, ultimate, xenarthra, hubble, faye,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8840 0.0237 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8346 0.0219 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8160 0.0220 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8059 0.0219 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8937 0.0224 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8384 0.0223 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9688 0.0214 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8785 0.0217 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9026 0.0214 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8229 0.0217 sec/batch
# Nearest to where: in, a, it, amperes, senna, manukau, danceable, germantown,
# Nearest to however: vorder, mahajanapadas, beginning, intersubjectivity, and, in, sovereignty, it,
# Nearest to these: atlanteans, are, some, vocalizations, callet, bundesl, all, sadr,
# Nearest to this: is, a, inevitable, which, fact, the, also, as,
# Nearest to into: the, before, worm, forming, starts, through, which, heart,
# Nearest to most: also, and, known, since, include, is, other, to,
# Nearest to one: six, three, zero, four, eight, nine, two, five,
# Nearest to eight: one, six, four, zero, three, seven, five, nine,
# Nearest to behind: pawn, biome, shareholding, recoiled, datum, denny, dunst, shook,
# Nearest to proposed: functionalist, explain, modified, odic, cyndi, tully, worked, argued,
# Nearest to taking: rumoured, organized, accordion, blocker, merv, abortifacient, vineyards, transcendent,
# Nearest to gold: medals, silver, ounce, coin, medalist, mania, feat, ores,
# Nearest to liberal: democrats, reynolds, bootlegging, afganistan, microcebus, tory, enrolls, holds,
# Nearest to hit: selling, kohoutek, danny, inhale, orientation, showed, run, skinner,
# Nearest to accepted: forbidden, motionless, dosing, offered, duly, sociale, observationally, complicate,
# Nearest to universe: noncanonical, bang, copernicus, satchel, ultimate, superheroes, hubble, kablooie,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7991 0.0224 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8493 0.0217 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7952 0.0223 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8687 0.0220 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8390 0.0221 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8540 0.0221 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9068 0.0127 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8254 0.0220 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8414 0.0221 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8455 0.0224 sec/batch
# Nearest to where: a, it, in, amperes, at, senna, manukau, danceable,
# Nearest to however: mahajanapadas, vorder, it, that, and, intersubjectivity, most, as,
# Nearest to these: atlanteans, are, some, vocalizations, all, callet, bundesl, ejected,
# Nearest to this: a, the, is, as, inevitable, fact, was, also,
# Nearest to into: the, before, starts, forming, worm, through, which, severin,
# Nearest to most: also, is, known, and, since, include, to, other,
# Nearest to one: three, six, zero, eight, four, nine, two, seven,
# Nearest to eight: one, six, zero, seven, three, four, nine, five,
# Nearest to behind: pawn, biome, datum, denny, recoiled, dunst, shareholding, stands,
# Nearest to proposed: functionalist, explain, odic, modified, cyndi, tully, indicates, worked,
# Nearest to taking: rumoured, merv, organized, accordion, abortifacient, blocker, dripped, these,
# Nearest to gold: medals, silver, ounce, copper, coin, awards, mania, sweethearts,
# Nearest to liberal: democrats, reynolds, enrolls, microcebus, bootlegging, kimmel, afganistan, tory,
# Nearest to hit: selling, inhale, kohoutek, showed, orientation, received, trumps, release,
# Nearest to accepted: forbidden, motionless, dosing, indulge, offered, duly, observationally, complicate,
# Nearest to universe: bang, noncanonical, copernicus, ultimate, satchel, superheroes, kablooie, hubble,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8151 0.0225 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8230 0.0215 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8483 0.0220 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7955 0.0218 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8347 0.0217 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8469 0.0217 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8780 0.0220 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7384 0.0223 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8058 0.0215 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8112 0.0218 sec/batch
# Nearest to where: a, in, it, amperes, at, senna, manukau, danceable,
# Nearest to however: it, mahajanapadas, that, vorder, number, most, beginning, in,
# Nearest to these: all, are, atlanteans, some, they, vocalizations, callet, however,
# Nearest to this: a, that, the, is, fact, which, also, in,
# Nearest to into: the, before, forming, starts, worm, through, which, chaldea,
# Nearest to most: also, and, to, is, since, known, include, the,
# Nearest to one: zero, three, six, eight, four, two, nine, five,
# Nearest to eight: one, six, zero, three, four, two, seven, nine,
# Nearest to behind: pawn, denny, dunst, recoiled, datum, biome, shareholding, stands,
# Nearest to proposed: odic, explain, functionalist, modified, cyndi, tully, worked, remaining,
# Nearest to taking: organized, dripped, merv, rumoured, accordion, blocker, these, abortifacient,
# Nearest to gold: medals, silver, copper, ores, precious, coin, quetzal, awards,
# Nearest to liberal: democrats, reynolds, microcebus, afganistan, bootlegging, tory, enrolls, pds,
# Nearest to hit: run, selling, kohoutek, trumps, received, inhale, release, showed,
# Nearest to accepted: forbidden, dosing, motionless, offered, duly, indulge, complicate, mammuthus,
# Nearest to universe: bang, noncanonical, copernicus, satchel, hubble, cosmic, kablooie, ultimate,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7438 0.0227 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8196 0.0222 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8428 0.0220 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8162 0.0221 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8205 0.0216 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8890 0.0215 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8503 0.0218 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8396 0.0219 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8454 0.0219 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8322 0.0215 sec/batch
# Nearest to where: a, in, it, amperes, senna, at, danceable, configuration,
# Nearest to however: mahajanapadas, it, in, and, vorder, the, that, most,
# Nearest to these: all, are, ejected, some, were, however, atlanteans, they,
# Nearest to this: a, that, is, the, fact, was, for, in,
# Nearest to into: before, the, starts, forming, through, worm, which, chaldea,
# Nearest to most: also, and, known, is, to, since, include, however,
# Nearest to one: zero, three, six, eight, four, two, nine, five,
# Nearest to eight: one, six, zero, four, three, two, seven, five,
# Nearest to behind: pawn, biome, dunst, recoiled, datum, stands, denny, shareholding,
# Nearest to proposed: functionalist, explain, odic, modified, cyndi, worked, indicates, argued,
# Nearest to taking: these, merv, organized, accordion, dripped, blocker, rumoured, transcendent,
# Nearest to gold: medals, silver, precious, coin, copper, awards, medalist, sweethearts,
# Nearest to liberal: democrats, reynolds, microcebus, bootlegging, enrolls, tory, afganistan, pds,
# Nearest to hit: received, selling, inhale, kohoutek, run, release, danny, soared,
# Nearest to accepted: forbidden, offered, dosing, motionless, duly, dua, sociale, complicate,
# Nearest to universe: bang, noncanonical, satchel, copernicus, ultimate, kablooie, hubble, endgame,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8478 0.0224 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8393 0.0217 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8128 0.0223 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8443 0.0218 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8653 0.0223 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8595 0.0219 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8133 0.0216 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8379 0.0220 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7997 0.0216 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8333 0.0215 sec/batch
# Nearest to where: a, in, it, danceable, senna, amperes, at, local,
# Nearest to however: in, most, and, it, the, mahajanapadas, as, that,
# Nearest to these: are, some, all, and, however, ejected, which, atlanteans,
# Nearest to this: is, a, the, in, has, which, as, fact,
# Nearest to into: the, before, through, forming, worm, which, starts, from,
# Nearest to most: and, also, to, include, known, however, is, as,
# Nearest to one: three, six, zero, eight, four, two, nine, five,
# Nearest to eight: six, one, zero, four, three, two, five, seven,
# Nearest to behind: pawn, recoiled, biome, datum, dunst, shareholding, denny, stands,
# Nearest to proposed: functionalist, explain, odic, cyndi, modified, tully, remaining, worked,
# Nearest to taking: these, organized, homeopathic, transcendent, merv, accordion, dripped, proscribe,
# Nearest to gold: medals, silver, copper, precious, coin, ores, sweethearts, awards,
# Nearest to liberal: democrats, reynolds, microcebus, bootlegging, enrolls, sadducees, tory, pds,
# Nearest to hit: run, selling, kohoutek, trumps, received, inhale, soared, danny,
# Nearest to accepted: forbidden, offered, motionless, dosing, observationally, complicate, duly, recognized,
# Nearest to universe: noncanonical, bang, copernicus, satchel, superheroes, kablooie, ultimate, prophecies,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8620 0.0231 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8309 0.0225 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9135 0.0218 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8963 0.0218 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8804 0.0215 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8528 0.0215 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7832 0.0215 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8564 0.0223 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7162 0.0217 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8665 0.0216 sec/batch
# Nearest to where: in, a, it, amperes, senna, at, danceable, manukau,
# Nearest to however: in, mahajanapadas, most, that, as, vorder, it, and,
# Nearest to these: are, some, all, atlanteans, ejected, they, callet, taking,
# Nearest to this: a, is, that, fact, for, which, the, as,
# Nearest to into: the, before, through, forming, starts, which, worm, incorporated,
# Nearest to most: also, and, known, include, is, to, other, as,
# Nearest to one: six, three, eight, zero, nine, four, two, five,
# Nearest to eight: one, six, zero, nine, seven, four, three, five,
# Nearest to behind: biome, pawn, datum, dunst, denny, shareholding, oracle, recoiled,
# Nearest to proposed: functionalist, explain, cyndi, odic, modified, tully, argued, completely,
# Nearest to taking: these, organized, accordion, dripped, homeopathic, rumoured, abortifacient, transcendent,
# Nearest to gold: medals, silver, coin, precious, copper, sweethearts, medalist, ounce,
# Nearest to liberal: democrats, reynolds, bootlegging, enrolls, microcebus, susan, acrylic, hcf,
# Nearest to hit: selling, received, kohoutek, run, danny, release, soared, embargoes,
# Nearest to accepted: forbidden, offered, dosing, motionless, duly, complicate, extraordinarily, mammuthus,
# Nearest to universe: noncanonical, bang, satchel, copernicus, ultimate, kablooie, superheroes, endgame,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8403 0.0234 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8331 0.0216 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
